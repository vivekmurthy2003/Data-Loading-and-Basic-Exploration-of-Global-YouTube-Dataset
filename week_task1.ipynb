# %% [markdown]
#  **Week Task 1**

# %%
# Import libraries
import numpy as np
import pandas as pd

# %%
# Load data csv file
#data = pd.read_csv('Global YouTube Statistics.csv')
data = pd.read_csv('/content/Global YouTube Statistics.csv',encoding ='latin1')
data
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
# shape : used find number of rows and columns in a data
data.shape
# 9994 rows,22 columns
# Out:
# (995, 28)

# %%
# head() : used to display first n number of rows , by default displays first 5 rows
data.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
# display first 5 rows
data.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
# display last 5 rows
data.tail(5)
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
# dtypes : used to find data type of each column
data.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                float64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# ...

# %%
# columns : print all the columns
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# select_dtypes: print only numerical columns(int,float)
num_data = data.select_dtypes(include=['int64','float64'])
num_data.columns
# Out:
# Index(['rank', 'subscribers', 'video views', 'uploads', 'video_views_rank',
#        'country_rank', 'channel_type_rank', 'video_views_for_the_last_30_days',
#        'lowest_monthly_earnings', 'highest_monthly_earnings',
#        'lowest_yearly_earnings', 'highest_yearly_earnings',
#        'subscribers_for_last_30_days', 'created_year', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# select_dtypes: print only categorical columns(columns which includes text)
cat_data = data.select_dtypes(include=['object'])
cat_data.columns
# Out:
# Index(['Youtuber', 'category', 'Title', 'Country', 'Abbreviation',
#        'channel_type', 'created_month'],
#       dtype='object')

# %%
# info : displays information about columns,missing values and memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
# describe  : Gives statistical report related to numerical data
data.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
# describe  : Gives statistical report related to categorical data
data.describe(include='object').T
# Out:
#               count unique            top freq
# Youtuber        995    995   Make Joke Of    1
# category        949     18  Entertainment  241
# Title           995    992        Preston    2
# Country         873     49  United States  313
# Abbreviation    873     49             US  313
# channel_type    965     14  Entertainment  304
# created_month   990     12            Jan  101

# %%
# unique : It gives distinct values
# find unique values in country
data.loc[:,'Country'].unique()
# Out:
# array(['India', 'United States', nan, 'Japan', 'Russia', 'South Korea',
#        'United Kingdom', 'Canada', 'Brazil', 'Argentina', 'Chile', 'Cuba',
#        'El Salvador', 'Pakistan', 'Philippines', 'Thailand', 'Colombia',
#        'Barbados', 'Mexico', 'United Arab Emirates', 'Spain',
#        'Saudi Arabia', 'Indonesia', 'Turkey', 'Venezuela', 'Kuwait',
#        'Jordan', 'Netherlands', 'Singapore', 'Australia', 'Italy',
#        'Germany', 'France', 'Sweden', 'Afghanistan', 'Ukraine', 'Latvia',
#        'Switzerland', 'Vietnam', 'Malaysia', 'China', 'Iraq', 'Egypt',
#        'Andorra', 'Ecuador', 'Morocco', 'Peru', 'Bangladesh', 'Finland',
#        'Samoa'], dtype=object)

# %%
# value_counts: count of each unique value
data.loc[:,'Country'].value_counts()
# Out:
# Country
# United States           313
# India                   168
# Brazil                   62
# United Kingdom           43
# Mexico                   33
# Indonesia                28
# Spain                    22
# Thailand                 18
# South Korea              17
# Russia                   16
# Canada                   15
# Argentina                13
# Philippines              12
# Colombia                 11
# Saudi Arabia              9
# Australia                 9
# Ukraine                   8
# United Arab Emirates      7
# Pakistan                  6
# Germany                   6
# France                    5
# Japan                     5
# Turkey                    4
# Sweden                    4
# Chile                     3
# Jordan                    3
# Netherlands               3
# Vietnam                   3
# Singapore                 3
# Ecuador                   2
# Egypt                     2
# Iraq                      2
# Italy                     2
# ...

# %%
data.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# drop duplicated rows
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)
